# %% [markdown]
# Databricks Notebook

# %%
print("Hello Databricks")

# %%
# %sql
SELECT 
  current_catalog()    AS current_catalog,
  current_database()   AS current_database;

# %%
# %sql
use catalog my_catalog_pratice;

# %%
# %sql
SELECT 
  current_catalog()    AS current_catalog,
  current_database()   AS current_database;
